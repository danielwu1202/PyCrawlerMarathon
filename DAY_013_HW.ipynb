# %%
import requests
from bs4 import BeautifulSoup

BASE_URL = 'https://www.ptt.cc'

# %% [markdown]
# # 印出最新文章的「作者」「標題」「時間」

# %%
url = BASE_URL + '/bbs/NBA/index.html'
r = requests.get(url)
nba_soup = BeautifulSoup(r.text, 'html.parser')

# 因為最下方為置底公告，從分隔線上開始爬
separation_line = nba_soup.select_one('.r-list-sep')
article_block = separation_line.find_previous_sibling('div')

title = article_block.select_one('.title').text.replace('\t', '').replace('\n', '').strip()
author = article_block.select_one('.author').text.strip()
date = article_block.select_one('.date').text.strip()

print(f'NBA版 最新的一篇文章為 ->')
print(f'標題: {title}')
print(f'作者: {author}')
print(f'時間: {date}')
# Out:
# NBA版 最新的一篇文章為 ->
# 標題: [花邊] Morris在Boban犯規後的反應
# 作者: Taco5566
# 時間: 8/20

# %% [markdown]
# # 印出第一頁所有文章的「作者」「標題」「時間」

# %%
def show_first_page_articles(soup):
    articles_block = soup.select('.r-ent')
    print(f'<共計 {len(articles_block)} 篇>')
    for index, article_block in enumerate(articles_block):
        title = article_block.select_one('.title').text.replace('\t', '').replace('\n', '').strip()
        if article_block.select_one('.title a'):
            url = BASE_URL + article_block.select_one('.title a').get('href')
        else:
            url = '-找不到網址-'
        author = article_block.select_one('.author').text.strip()
        date = article_block.select_one('.date').text.strip()
        print(f'———————————————— {index+1:>2d} ————————————————')
        print(f'標題: {title}')
        print(f'網址: {url}')
        print(f'作者: {author}')
        print(f'時間: {date}')


print(f'NBA版 第一頁所有文章(包含置底公告)：')
show_first_page_articles(nba_soup)
# Out:
# NBA版 第一頁所有文章(包含置底公告)：
# <共計 20 篇>
# ————————————————  1 ————————————————
# 標題: [BOX ] Nets 99:104 Raptors
# 網址: https://www.ptt.cc/bbs/NBA/M.1597868214.A.F3E.html
# 作者: Rambo
# 時間: 8/20
# ————————————————  2 ————————————————
# 標題: [討論] NBA TV
# 網址: https://www.ptt.cc/bbs/NBA/M.1597872578.A.ACA.html
# 作者: Yukan
# 時間: 8/20
# ————————————————  3 ————————————————
# 標題: [Live] 七六人 @ 超賽
# 網址: https://www.ptt.cc/bbs/NBA/M.1597874406.A.B6C.html
# 作者: Rambo
# 時間: 8/20
# ————————————————  4 ————————————————
# 標題: [BOX ] Jazz 124:105 Nuggets
# 網址: https://www.ptt.cc/bbs/NBA/M.1597876455.A.7D7.html
# 作者: Rambo
# 時間: 8/20
# ————————————————  5 ————————————————
# 標題: [Live] 獨行俠 @ 快艇
# 網址: https://www.ptt.cc/bbs/NBA/M.1597883437.A.DA7.html
# 作者: Rambo
# 時間: 8/20
# ————————————————  6 ————————————————
# 標題: [新聞] 林書豪入台籍仍算美國外援　李戡86字分析
# 網址: https://www.ptt.cc/bbs/NBA/M.1597883483.A.783.html
# 作者: whj0530
# 時間: 8/20
# ————————————————  7 ————————————————
# 標題: [花邊]無緣跟安東尼當隊友 詹皇：任何事發生都
# 網址: https://www.ptt.cc/bbs/NBA/M.1597884949.A.781.html
# 作者: sodistrues
# 時間: 8/20
# ————————————————  8 ————————————————
# 標題: [BOX ] Sixers 101:128 Celtics
# 網址: https://www.ptt.cc/bbs/NBA/M.1597885806.A.8E5.html
# 作者: Rambo
# 時間: 8/20
# ————————————————  9 ————————————————
# 標題: [討論]  今年的LBJ還沒有進入季後賽模式？
# 網址: https://www.ptt.cc/bbs/NBA/M.1597889571.A.48D.html
# 作者: sam28711
# 時間: 8/20
# ———————————————— 10 ————————————————
# 標題: [花邊] Walker：JT和JB是超級球星，我喜歡在他們
# 網址: https://www.ptt.cc/bbs/NBA/M.1597889652.A.BC0.html
# 作者: Muma5566
# 時間: 8/20
# ———————————————— 11 ————————————————
# 標題: [BOX ] Mavericks 127:114 Clippers
# 網址: https://www.ptt.cc/bbs/NBA/M.1597896009.A.DCC.html
# 作者: Rambo
# 時間: 8/20
# ———————————————— 12 ————————————————
# 標題: [討論] 今年季後賽是不是下剋上最佳機會
# 網址: https://www.ptt.cc/bbs/NBA/M.1597896348.A.EBB.html
# 作者: ctw01
# 時間: 8/20
# ———————————————— 13 ————————————————
# 標題: (本文已被刪除) [gg8n8nd34ss]
# 網址: -找不到網址-
# 作者: -
# 時間: 8/20
# ———————————————— 14 ————————————————
# 標題: [情報] Donci 生涯前兩場季後賽得70分 史上第二人
# 網址: https://www.ptt.cc/bbs/NBA/M.1597898025.A.8C1.html
# 作者: thnlkj0665
# 時間: 8/20
# ———————————————— 15 ————————————————
# 標題: [討論] 沒有觀眾的比賽是否少了點什麼
# 網址: https://www.ptt.cc/bbs/NBA/M.1597901143.A.ECF.html
# 作者: mm0312
# 時間: 8/20
# ———————————————— 16 ————————————————
# 標題: [花邊] Morris在Boban犯規後的反應
# 網址: https://www.ptt.cc/bbs/NBA/M.1597902885.A.EF8.html
# 作者: Taco5566
# 時間: 8/20
# ———————————————— 17 ————————————————
# 標題: [公告] 板規v6.8
# 網址: https://www.ptt.cc/bbs/NBA/M.1558698194.A.1DC.html
# 作者: Vedan
# 時間: 5/24
# ———————————————— 18 ————————————————
# 標題: [公告] 第一次被退文，可在三天後刪除退文
# 網址: https://www.ptt.cc/bbs/NBA/M.1583725468.A.281.html
# 作者: Vedan
# 時間: 3/09
# ———————————————— 19 ————————————————
# 標題: [公告] 8/15實施季後賽條款 以及提醒事項(發P)
# 網址: https://www.ptt.cc/bbs/NBA/M.1597332070.A.6E2.html
# 作者: namie810303
# 時間: 8/13
# ———————————————— 20 ————————————————
# 標題: [情報] Playoffs Schedule 19–20
# 網址: https://www.ptt.cc/bbs/NBA/M.1597695044.A.F65.html
# 作者: Acetoxy
# 時間: 8/18

# %% [markdown]
# # 試著爬爬看其他版的文章

# %%
# 爬取熱門看板
print('取得目前PTT的熱門看板...')
url = f'{BASE_URL}/bbs/index.html'
r = requests.get(url)
hot_soup = BeautifulSoup(r.text, 'html.parser')
boards_block = hot_soup.select('.b-ent')

rank = input('請輸入想看的名次(例如"1")：') or '1'
if not rank.isdigit():
    print('輸入格式錯誤!')
    rank = '1'
rank = int(rank)
print('============================')

board_block = boards_block[rank-1]
board_url = board_block.select_one('a').get('href')
board_url = f'{BASE_URL}{board_url}'
board_name = board_block.select_one('.board-name').text.strip()
board_category = board_block.select_one('.board-class').text.strip()

# 爬取選定的看板
r = requests.get(board_url, cookies={'over18': '1'})
board_soup = BeautifulSoup(r.text, 'html.parser')

print(f'{board_name}版({board_category}) 第一頁所有文章(包含置底公告)：')
print(board_url)
show_first_page_articles(board_soup)
# Out:
# 取得目前PTT的熱門看板...
# 請輸入想看的名次(例如"1")：1
# ============================
# Gossiping版(綜合) 第一頁所有文章(包含置底公告)：
# https://www.ptt.cc/bbs/Gossiping/index.html
# <共計 21 篇>
# ————————————————  1 ————————————————
# 標題: [問卦] 法官是不是不需負責所以才隨意判？
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902449.A.73F.html
# 作者: ray90910
# 時間: 8/20
# ————————————————  2 ————————————————
# 標題: (本文已被刪除) [cheinshin]
# 網址: -找不到網址-
# 作者: -
# 時間: 8/20
# ————————————————  3 ————————————————
# 標題: Re: [新聞] 瑪莎拉蒂與foodpanda的距離！無牌海神警
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902464.A.AEB.html
# 作者: whywhywhy
# 時間: 8/20
# ————————————————  4 ————————————————
# 標題: [問卦] 毒品價格是不是要飛天了?
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902478.A.651.html
# 作者: qppq
# 時間: 8/20
# ————————————————  5 ————————————————
# 標題: [問卦] Google信箱是不是掛了??
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902508.A.9C5.html
# 作者: berberis
# 時間: 8/20
# ————————————————  6 ————————————————
# 標題: Re: [問卦] 為什麼不是檢討法律 而是法官
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902512.A.42A.html
# 作者: syearth
# 時間: 8/20
# ————————————————  7 ————————————————
# 標題: Re: [新聞] 斬首老母無罪釋放 鄰里憂：他又殺人
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902545.A.E29.html
# 作者: famas2200
# 時間: 8/20
# ————————————————  8 ————————————————
# 標題: [新聞] 在線等！網質疑「PTT土豪哥」有錢全是造
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902561.A.8B6.html
# 作者: nba887215
# 時間: 8/20
# ————————————————  9 ————————————————
# 標題: [新聞] 索馬利亞抗議我侵犯主權 外交部：一索原
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902597.A.1DD.html
# 作者: koei5566
# 時間: 8/20
# ———————————————— 10 ————————————————
# 標題: Re: [新聞] 彰化居家檢疫者爆「隔離3天要我自行去篩
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902613.A.B7F.html
# 作者: smm5457
# 時間: 8/20
# ———————————————— 11 ————————————————
# 標題: Re: [新聞] 馬祖徵中小學老師「不用教師證」！月薪5
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902638.A.DB3.html
# 作者: Refauth
# 時間: 8/20
# ———————————————— 12 ————————————————
# 標題: [問卦] 作xx學徒會不會還沒成師腰椎先壞？
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902666.A.AB1.html
# 作者: gentleman45
# 時間: 8/20
# ———————————————— 13 ————————————————
# 標題: Re: [新聞] 馬祖徵中小學老師「不用教師證」！月薪5
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902765.A.37B.html
# 作者: myIDis7
# 時間: 8/20
# ———————————————— 14 ————————————————
# 標題: [問卦] 愛莉莎莎 愛麗莎莎 艾莉莎莎選一個當女士
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902794.A.C42.html
# 作者: muscatsss
# 時間: 8/20
# ———————————————— 15 ————————————————
# 標題: Re: [問卦] 彰化普篩事件    怎麼大順風打到變逆風？
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902820.A.B73.html
# 作者: smallweek
# 時間: 8/20
# ———————————————— 16 ————————————————
# 標題: Re: [新聞] 瑪莎拉蒂與foodpanda的距離！無牌海神警
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597902866.A.A2F.html
# 作者: Lineage097
# 時間: 8/20
# ———————————————— 17 ————————————————
# 標題: [公告] 八卦板板規(2020.07.21)
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1595260807.A.E89.html
# 作者: seabox
# 時間: 7/21
# ———————————————— 18 ————————————————
# 標題: [協尋] 8/12 屏東 萬順路與崙中路口 行車紀錄器
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597395423.A.0FC.html
# 作者: water112
# 時間: 8/14
# ———————————————— 19 ————————————————
# 標題: [協尋] 8/12  12:10~12:40行經花東鹽寮北上影像
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597380236.A.3AB.html
# 作者: monarch0301
# 時間: 8/14
# ———————————————— 20 ————————————————
# 標題: [協尋] 朋友8/17在花蓮豐濱區失去聯繫
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597727512.A.154.html
# 作者: yenling1224
# 時間: 8/18
# ———————————————— 21 ————————————————
# 標題: Fw: [徵求]行車紀錄8/17台南新市區永就里am7-8
# 網址: https://www.ptt.cc/bbs/Gossiping/M.1597762934.A.F53.html
# 作者: ROCKMAX
# 時間: 8/18
