# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"13021362480","type":"WatchEvent","actor":{"id":61539647,"login":"nickfnblum","display_login":"nickfnblum","gravatar_id":"","url":"https://api.github.com/users/nickfnblum","avatar_url":"https://avatars.githubusercontent.com/u/61539647?"},"repo":{"id":21627540,"name":"youtube/geo-search-tool","url":"https://api.github.com/repos/youtube/geo-search-tool"},"payload":{"action":"started"},"public":true,"created_at":"2020-07-27T06:07:50Z","org":{"id":4052902,"login":"youtube","gravatar_id":"","url":"https://api.github.com/orgs/youtube","avatar_url":"https://avatars.githubusercontent.com/u/4052902?"}},{"id":"13021362470","type":"PushEvent","actor":{"id":54281882,"login":"datarods-svc","display_login":"datarods-svc","gravatar_id":"","url":"https://api.github.com/users/datarods-svc","avatar_url":"https://avatars.githubusercontent.com/u/54281882?"},"repo":{"id":270887418,"name":"feedarchive/freenode-feedbot-live","url":"https://api.github.com/repos/feedarchive/freenode-feedbot-live"},"p
# ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '13021362480',
#   'type': 'WatchEvent',
#   'actor': {'id': 61539647,
#    'login': 'nickfnblum',
#    'display_login': 'nickfnblum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nickfnblum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61539647?'},
#   'repo': {'id': 21627540,
#    'name': 'youtube/geo-search-tool',
#    'url': 'https://api.github.com/repos/youtube/geo-search-tool'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-07-27T06:07:50Z',
#   'org': {'id': 4052902,
#    'login': 'youtube',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/youtube',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4052902?'}},
#  {'id': '13021362470',
#   'type': 'PushEvent',
#   'actor': {'id': 54281882,
#    'login': 'datarods-svc',
#    'display_login': 'datarods-svc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datarods-svc',
# ...

# %%
q = requests.get('https://cat-fact.herokuapp.com/facts')
q.text
# Out:
# '{"all":[{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":7,"userUpvoted":null},{"_id":"59a60b8e6acf530020f3586e","text":"Cat owners are 17% more likely to have a graduate degree than non cat owners.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":7,"userUpvoted":null},{"_id":"58e009550aac31001185ed12","text":"The oldest cat video on YouTube dates back to 1894.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":6,"userUpvoted":null},{"_id":"58e008340aac31001185ecfb","text":"Cats sleep 70% of their lives.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir
# ...

# %%
json.loads(q.text)
# Out:
# {'all': [{'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '58e009550aac31001185ed12',
#    'text': 'The oldest cat video on YouTube dates back to 1894.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
# ...
